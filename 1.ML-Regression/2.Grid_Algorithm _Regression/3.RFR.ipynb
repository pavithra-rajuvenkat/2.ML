# %%
import pandas as pd
import numpy as np

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset= pd.get_dummies(dataset, dtype = int, drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[["charges"]]
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(independent,dependent, test_size=0.30, random_state=0)
x_train,x_test,y_train,y_test
# Out:
# (      age     bmi  children  sex_male  smoker_yes
#  1163   18  28.215         0         0           0
#  196    39  32.800         0         0           0
#  438    52  46.750         5         0           0
#  183    44  26.410         0         0           0
#  1298   33  27.455         2         1           0
#  ...   ...     ...       ...       ...         ...
#  763    27  26.030         0         1           0
#  835    42  35.970         2         1           0
#  1216   40  25.080         0         1           0
#  559    19  35.530         0         1           0
#  684    33  18.500         1         0           0
#
#  [936 rows x 5 columns],
#        age     bmi  children  sex_male  smoker_yes
#  578    52  30.200         1         1           0
#  610    47  29.370         1         0           0
#  569    48  40.565         2         1           1
#  1034   61  38.380         0         1           0
#  198    51  18.050         0         0           0
#  ...   ...     ...       ...       ...         ...
#  1261   28  37.100         1         1           0
#  494    21  25.700         4         1           1
#  97     55  38.280         0         1           0
#  418    64  39.160         1         1           0
#  920    62  25.000         0         0           0
#
#  [402 rows x 5 columns],
#            charges
#  1163   2200.83085
#  196    5649.71500
#  438   12592.53450
#  183    7419.47790
#  1298   5261.46945
#  ...           ...
#  763    3070.80870
#  835    7160.33030
#  1216   5415.66120
#  559    1646.42970
#  684    4766.02200
#
#  [936 rows x 1 columns],
#            charges
#  578    9724.53000
#  610    8547.69130
#  569   45702.02235
#  1034  12950.07120
#  198    9644.25250
#  ...           ...
#  1261   3277.16100
#  494   17942.10600
#  97    10226.28420
#  418   14418.28040
#  920   13451.12200
#
#  [402 rows x 1 columns])

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)
x_train
# Out:
# array([[-1.5330973 , -0.40713453, -0.89833872, -0.97676557, -0.50466988],
#        [-0.03364163,  0.32855417, -0.89833872, -0.97676557, -0.50466988],
#        [ 0.89459283,  2.56690911,  3.25603402, -0.97676557, -0.50466988],
#        ...,
#        [ 0.03776102, -0.91016269, -0.89833872,  1.02378711, -0.50466988],
#        [-1.46169465,  0.76659782, -0.89833872,  1.02378711, -0.50466988],
#        [-0.46205754, -1.96596021, -0.06746417, -0.97676557, -0.50466988]])

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
param_grid= {'criterion':["squared_error", "friedman_mse", "absolute_error", "poisson"],'n_estimators':[10,50,100], 'max_features':['sqrt', 'log2',None]}
grid=GridSearchCV(RandomForestRegressor(),param_grid,refit=True, verbose=3,n_jobs=-1)
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# C:\anaconda\Anaconda\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': ['sqrt', 'log2', None],
#                          'n_estimators': [10, 50, 100]},
#              verbose=3)

# %%
re=grid.cv_results_
grid_pred=grid.predict(x_test)
print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'criterion': 'friedman_mse', 'max_features': 'log2', 'n_estimators': 50}:

# %%
from sklearn.metrics import r2_score
r_score=r2_score(y_test,grid_pred)
r_score
# Out:
# 0.8673414202978083

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.100786      0.011609         0.009589        0.001442
# 1        0.322060      0.018615         0.019011        0.006042
# 2        0.647213      0.011150         0.023106        0.003883
# 3        0.073113      0.004236         0.006483        0.002887
# 4        0.308286      0.008493         0.016333        0.004549
# 5        0.630725      0.013419         0.026234        0.004536
# 6        0.100105      0.016784         0.006777        0.003475
# 7        0.404518      0.018978         0.015865        0.003728
# 8        0.783681      0.035094         0.025673        0.005133
# 9        0.066432      0.005185         0.007662        0.005261
# 10       0.294070      0.021304         0.021346        0.005026
# 11       0.628098      0.014555         0.028052        0.004264
# 12       0.068673      0.007610         0.004203        0.003231
# 13       0.325127      0.042379         0.018161        0.005072
# 14       0.757435      0.026401         0.033490        0.002872
# 15       0.098870      0.006156         0.007117        0.007270
# 16       0.471348      0.009101         0.019280        0.006888
# 17       0.961746      0.018342         0.030208        0.005074
# 18       0.199172      0.010076         0.006123        0.004042
# 19       1.011945      0.020571         0.013879        0.003639
# 20       1.948582      0.027826         0.030029        0.000830
# 21       0.205614      0.002059         0.008622        0.001895
# 22       0.995683      0.019147         0.015670        0.002807
# 23       1.963962      0.015991         0.025710        0.005541
# 24       0.332478      0.017197         0.007904        0.003929
# 25       1.654960      0.026658         0.014807        0.002171
# 26       3.290507      0.025135         0.027480        0.004687
# 27       0.109073      0.006299         0.012542        0.003364
# 28       0.529416      0.005086         0.024581        0.004410
# 29       1.087630      0.016103         0.030070        0.001987
# 30       0.114423      0.006928         0.007483        0.005234
# 31       0.561533      0.017804         0.018259        0.003946
# 32       1.113548      0.018598         0.027852        0.007015
# 33       0.132872      0.008120         0.007043        0.004318
# 34       0.650599      0.010893         0.016048        0.004671
# 35       1.190017      0.049329         0.023794        0.003790
#
#    param_criterion param_max_features  param_n_estimators  \
# 0    squared_error               sqrt                  10
# 1    squared_error               sqrt                  50
# 2    squared_error               sqrt                 100
# 3    squared_error               log2                  10
# 4    squared_error               log2                  50
# 5    squared_error               log2                 100
# 6    squared_error               None                  10
# 7    squared_error               None                  50
# 8    squared_error               None                 100
# 9     friedman_mse               sqrt                  10
# 10    friedman_mse               sqrt                  50
# 11    friedman_mse               sqrt                 100
# 12    friedman_mse               log2                  10
# 13    friedman_mse               log2                  50
# 14    friedman_mse               log2                 100
# 15    friedman_mse               None                  10
# 16    friedman_mse               None                  50
# 17    friedman_mse               None                 100
# 18  absolute_error               sqrt                  10
# 19  absolute_error               sqrt                  50
# 20  absolute_error               sqrt                 100
# 21  absolute_error               log2                  10
# 22  absolute_error               log2                  50
# 23  absolute_error               log2                 100
# 24  absolute_error               None                  10
# 25  absolute_error               None                  50
# 26  absolute_error               None                 100
# 27         poisson               sqrt                  10
# 28         poisson               sqrt                  50
# 29         poisson               sqrt                 100
# 30         poisson               log2                  10
# 31         poisson               log2                  50
# 32         poisson               log2                 100
# 33         poisson               None                  10
# 34         poisson               None                  50
# 35         poisson               None                 100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.823203
# 1   {'criterion': 'squared_error', 'max_features':...           0.857155
# 2   {'criterion': 'squared_error', 'max_features':...           0.866553
# 3   {'criterion': 'squared_error', 'max_features':...           0.839518
# 4   {'criterion': 'squared_error', 'max_features':...           0.860809
# 5   {'criterion': 'squared_error', 'max_features':...           0.864760
# 6   {'criterion': 'squared_error', 'max_features':...           0.855309
# 7   {'criterion': 'squared_error', 'max_features':...           0.858750
# 8   {'criterion': 'squared_error', 'max_features':...           0.860961
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.822051
# 10  {'criterion': 'friedman_mse', 'max_features': ...           0.854658
# 11  {'criterion': 'friedman_mse', 'max_features': ...           0.867510
# 12  {'criterion': 'friedman_mse', 'max_features': ...           0.825003
# 13  {'criterion': 'friedman_mse', 'max_features': ...           0.861333
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.868333
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.846537
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.857656
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.861936
# 18  {'criterion': 'absolute_error', 'max_features'...           0.838673
# 19  {'criterion': 'absolute_error', 'max_features'...           0.855070
# 20  {'criterion': 'absolute_error', 'max_features'...           0.857440
# 21  {'criterion': 'absolute_error', 'max_features'...           0.827813
# 22  {'criterion': 'absolute_error', 'max_features'...           0.852661
# 23  {'criterion': 'absolute_error', 'max_features'...           0.855394
# 24  {'criterion': 'absolute_error', 'max_features'...           0.819869
# 25  {'criterion': 'absolute_error', 'max_features'...           0.845133
# 26  {'criterion': 'absolute_error', 'max_features'...           0.852189
# 27  {'criterion': 'poisson', 'max_features': 'sqrt...           0.858438
# 28  {'criterion': 'poisson', 'max_features': 'sqrt...           0.866152
# 29  {'criterion': 'poisson', 'max_features': 'sqrt...           0.862288
# 30  {'criterion': 'poisson', 'max_features': 'log2...           0.855835
# 31  {'criterion': 'poisson', 'max_features': 'log2...           0.850831
# 32  {'criterion': 'poisson', 'max_features': 'log2...           0.861479
# 33  {'criterion': 'poisson', 'max_features': None,...           0.847823
# 34  {'criterion': 'poisson', 'max_features': None,...           0.862300
# 35  {'criterion': 'poisson', 'max_features': None,...           0.867906
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.780607           0.759879           0.798486
# 1            0.786931           0.806497           0.830174
# 2            0.790622           0.806878           0.825792
# 3            0.776721           0.784995           0.810200
# 4            0.784671           0.805415           0.819469
# 5            0.793406           0.799626           0.829888
# 6            0.748629           0.807685           0.785525
# 7            0.768153           0.811785           0.802026
# 8            0.777565           0.815716           0.797881
# 9            0.792987           0.762605           0.798210
# 10           0.779777           0.799955           0.821931
# 11           0.791339           0.804781           0.821733
# 12           0.782919           0.807444           0.818500
# 13           0.798736           0.815460           0.834610
# 14           0.789410           0.808218           0.827774
# 15           0.732153           0.791814           0.753905
# 16           0.756520           0.809476           0.808346
# 17           0.766330           0.812999           0.808496
# 18           0.764355           0.791552           0.815978
# 19           0.796121           0.799851           0.827376
# 20           0.797525           0.812060           0.833050
# 21           0.725362           0.797477           0.802398
# 22           0.798920           0.810823           0.823613
# 23           0.787699           0.813426           0.829190
# 24           0.748458           0.781684           0.788243
# 25           0.776819           0.786187           0.796196
# 26           0.778616           0.798543           0.801229
# 27           0.754599           0.779538           0.816384
# 28           0.784498           0.812012           0.824798
# 29           0.792576           0.806220           0.832093
# 30           0.791428           0.796318           0.813622
# 31           0.783349           0.806922           0.832491
# 32           0.795810           0.805772           0.833600
# 33           0.742262           0.803439           0.789573
# 34           0.769293           0.815652           0.795348
# 35           0.765595           0.820855           0.804584
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.755451         0.783525        0.025116               33
# 1            0.766183         0.809388        0.031916               12
# 2            0.772712         0.812511        0.032223                4
# 3            0.755623         0.793411        0.028931               27
# 4            0.768465         0.807766        0.031730               14
# 5            0.771705         0.811877        0.032330                8
# 6            0.750491         0.789528        0.039672               30
# 7            0.767038         0.801550        0.033714               22
# 8            0.767879         0.804001        0.032933               19
# 9            0.751426         0.785456        0.025451               32
# 10           0.770393         0.805343        0.030369               17
# 11           0.771278         0.811328        0.032592               10
# 12           0.766064         0.799986        0.022209               24
# 13           0.768725         0.815773        0.031415                1
# 14           0.766853         0.812118        0.034598                6
# 15           0.745077         0.773897        0.041401               36
# 16           0.768442         0.800088        0.035693               23
# 17           0.767044         0.803361        0.035328               20
# 18           0.762399         0.794592        0.029531               26
# 19           0.765361         0.808756        0.030377               13
# 20           0.769240         0.813863        0.030095                2
# 21           0.763493         0.783309        0.035486               34
# 22           0.768896         0.810983        0.027617               11
# 23           0.772278         0.811597        0.029489                9
# 24           0.748526         0.777356        0.026873               35
# 25           0.759430         0.792753        0.028855               28
# 26           0.762486         0.798613        0.030273               25
# 27           0.743901         0.790572        0.042109               29
# 28           0.773508         0.812193        0.032662                5
# 29           0.767248         0.812085        0.032699                7
# 30           0.764039         0.804248        0.030309               18
# 31           0.763879         0.807495        0.031587               15
# 32           0.770417         0.813415        0.031416                3
# 33           0.747302         0.786080        0.038857               31
# 34           0.768700         0.802259        0.034771               21
# 35           0.768874         0.805563        0.037590               16

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
age_input=float(input("Age:"))
bmi_input=float(input("Bmi:"))
children=float(input("Children:"))
sex_male=int(input("Sex_Male 0 or 1:"))
smoker_yes=int(input("Smoker yes 0 or 1:"))
# Out:
# Age: 32
# Bmi: 25
# Children: 1
# Sex_Male 0 or 1: 0
# Smoker yes 0 or 1: 0

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children,sex_male,smoker_yes]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[15834.076433]
