# %%
import pandas as pd
import numpy as np

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset= pd.get_dummies(dataset, dtype = int, drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[["charges"]]
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
param_grid= {'criterion':["squared_error", "friedman_mse", "absolute_error", "poisson"],'n_estimators':[10,50,100], 'max_features':['sqrt', 'log2',None]}
grid=GridSearchCV(RandomForestRegressor(),param_grid,refit=True, verbose=3,n_jobs=-1)
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# C:\anaconda\Anaconda\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': ['sqrt', 'log2', None],
#                          'n_estimators': [10, 50, 100]},
#              verbose=3)

# %%
re=grid.cv_results_
print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'criterion': 'poisson', 'max_features': 'sqrt', 'n_estimators': 100}:

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.353965      0.280531         0.013895        0.002380
# 1        1.044969      0.279765         0.058076        0.014642
# 2        1.635998      0.209732         0.066170        0.009656
# 3        0.232779      0.033714         0.011851        0.011684
# 4        1.210844      0.617955         0.024006        0.008908
# 5        2.019831      0.174470         0.054301        0.022682
# 6        0.802766      1.004459         0.016719        0.022711
# 7        1.179853      0.089288         0.039357        0.031244
# 8        2.739011      0.039242         0.090038        0.017504
# 9        0.838953      1.010185         0.025131        0.027879
# 10       1.023660      0.043466         0.056503        0.021202
# 11       2.069788      0.082346         0.071104        0.021607
# 12       0.454629      0.292711         0.011714        0.002509
# 13       0.870089      0.074333         0.041264        0.020980
# 14       2.134032      0.075515         0.090009        0.012508
# 15       0.382705      0.056570         0.035549        0.025725
# 16       1.390314      0.108750         0.079670        0.013876
# 17       3.112554      0.077837         0.097866        0.014871
# 18       0.928667      0.077619         0.018143        0.017504
# 19       4.229355      0.084810         0.056071        0.043165
# 20       8.465089      0.240851         0.106301        0.006996
# 21       0.946573      0.026748         0.029943        0.033478
# 22       4.320721      0.071459         0.032641        0.033331
# 23       8.583114      0.110855         0.111631        0.012308
# 24       1.569084      0.034552         0.022816        0.036427
# 25       7.406216      0.122423         0.050927        0.040315
# 26      14.483893      0.441023         0.099859        0.034715
# 27       0.509750      0.022704         0.010249        0.006012
# 28       2.040434      0.063678         0.063116        0.038645
# 29       3.770277      0.339930         0.070922        0.034430
# 30       0.432386      0.028714         0.006026        0.005930
# 31       1.638770      0.120206         0.048949        0.025930
# 32       3.286244      0.163900         0.068508        0.032220
# 33       0.571602      0.058961         0.013534        0.003131
# 34       2.193285      0.149093         0.078341        0.034334
# 35       3.700373      0.344343         0.049777        0.019650
#
#    param_criterion param_max_features  param_n_estimators  \
# 0    squared_error               sqrt                  10
# 1    squared_error               sqrt                  50
# 2    squared_error               sqrt                 100
# 3    squared_error               log2                  10
# 4    squared_error               log2                  50
# 5    squared_error               log2                 100
# 6    squared_error               None                  10
# 7    squared_error               None                  50
# 8    squared_error               None                 100
# 9     friedman_mse               sqrt                  10
# 10    friedman_mse               sqrt                  50
# 11    friedman_mse               sqrt                 100
# 12    friedman_mse               log2                  10
# 13    friedman_mse               log2                  50
# 14    friedman_mse               log2                 100
# 15    friedman_mse               None                  10
# 16    friedman_mse               None                  50
# 17    friedman_mse               None                 100
# 18  absolute_error               sqrt                  10
# 19  absolute_error               sqrt                  50
# 20  absolute_error               sqrt                 100
# 21  absolute_error               log2                  10
# 22  absolute_error               log2                  50
# 23  absolute_error               log2                 100
# 24  absolute_error               None                  10
# 25  absolute_error               None                  50
# 26  absolute_error               None                 100
# 27         poisson               sqrt                  10
# 28         poisson               sqrt                  50
# 29         poisson               sqrt                 100
# 30         poisson               log2                  10
# 31         poisson               log2                  50
# 32         poisson               log2                 100
# 33         poisson               None                  10
# 34         poisson               None                  50
# 35         poisson               None                 100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.854823
# 1   {'criterion': 'squared_error', 'max_features':...           0.854025
# 2   {'criterion': 'squared_error', 'max_features':...           0.858040
# 3   {'criterion': 'squared_error', 'max_features':...           0.843393
# 4   {'criterion': 'squared_error', 'max_features':...           0.854387
# 5   {'criterion': 'squared_error', 'max_features':...           0.858204
# 6   {'criterion': 'squared_error', 'max_features':...           0.840122
# 7   {'criterion': 'squared_error', 'max_features':...           0.847308
# 8   {'criterion': 'squared_error', 'max_features':...           0.847947
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.849829
# 10  {'criterion': 'friedman_mse', 'max_features': ...           0.857474
# 11  {'criterion': 'friedman_mse', 'max_features': ...           0.856655
# 12  {'criterion': 'friedman_mse', 'max_features': ...           0.847799
# 13  {'criterion': 'friedman_mse', 'max_features': ...           0.858136
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.857470
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.839485
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.851534
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.845485
# 18  {'criterion': 'absolute_error', 'max_features'...           0.841055
# 19  {'criterion': 'absolute_error', 'max_features'...           0.856334
# 20  {'criterion': 'absolute_error', 'max_features'...           0.854090
# 21  {'criterion': 'absolute_error', 'max_features'...           0.843608
# 22  {'criterion': 'absolute_error', 'max_features'...           0.849239
# 23  {'criterion': 'absolute_error', 'max_features'...           0.858040
# 24  {'criterion': 'absolute_error', 'max_features'...           0.804773
# 25  {'criterion': 'absolute_error', 'max_features'...           0.830999
# 26  {'criterion': 'absolute_error', 'max_features'...           0.836328
# 27  {'criterion': 'poisson', 'max_features': 'sqrt...           0.848694
# 28  {'criterion': 'poisson', 'max_features': 'sqrt...           0.858103
# 29  {'criterion': 'poisson', 'max_features': 'sqrt...           0.861583
# 30  {'criterion': 'poisson', 'max_features': 'log2...           0.847489
# 31  {'criterion': 'poisson', 'max_features': 'log2...           0.854426
# 32  {'criterion': 'poisson', 'max_features': 'log2...           0.856804
# 33  {'criterion': 'poisson', 'max_features': None,...           0.843765
# 34  {'criterion': 'poisson', 'max_features': None,...           0.843676
# 35  {'criterion': 'poisson', 'max_features': None,...           0.850107
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.746284           0.850207           0.809536
# 1            0.776759           0.857977           0.824125
# 2            0.785433           0.856112           0.830400
# 3            0.751502           0.841337           0.803544
# 4            0.786571           0.858307           0.826644
# 5            0.780693           0.853018           0.823780
# 6            0.757534           0.851265           0.807729
# 7            0.770854           0.853772           0.816654
# 8            0.772053           0.859770           0.815479
# 9            0.768270           0.849960           0.820734
# 10           0.772535           0.858041           0.829137
# 11           0.780488           0.861905           0.829564
# 12           0.750626           0.836515           0.820926
# 13           0.777272           0.861961           0.825946
# 14           0.779633           0.859514           0.828537
# 15           0.746995           0.828059           0.809560
# 16           0.771816           0.855539           0.817075
# 17           0.769727           0.853450           0.820621
# 18           0.756998           0.827580           0.813397
# 19           0.780216           0.853881           0.823617
# 20           0.779271           0.859068           0.831567
# 21           0.759053           0.811220           0.826652
# 22           0.774360           0.856455           0.828495
# 23           0.781455           0.858531           0.826106
# 24           0.754079           0.848785           0.819655
# 25           0.771604           0.849401           0.820384
# 26           0.763605           0.850337           0.821806
# 27           0.766669           0.846721           0.801607
# 28           0.776727           0.861519           0.823368
# 29           0.780723           0.861734           0.829318
# 30           0.784053           0.836968           0.804062
# 31           0.781991           0.858809           0.826248
# 32           0.779754           0.864871           0.827811
# 33           0.766146           0.833916           0.814946
# 34           0.767425           0.855008           0.818249
# 35           0.768187           0.857133           0.818766
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.809901         0.814150        0.038986               32
# 1            0.836550         0.829887        0.029230               16
# 2            0.839560         0.833909        0.026342                3
# 3            0.806253         0.809206        0.033381               35
# 4            0.837590         0.832700        0.025747                8
# 5            0.839756         0.831090        0.027873               12
# 6            0.818150         0.814960        0.032593               31
# 7            0.834208         0.824559        0.029701               22
# 8            0.831842         0.825418        0.030579               19
# 9            0.809749         0.819708        0.030228               27
# 10           0.836603         0.830758        0.031256               14
# 11           0.837797         0.833282        0.028938                5
# 12           0.831891         0.817551        0.034556               28
# 13           0.840677         0.832799        0.030609                6
# 14           0.837571         0.832545        0.028947               10
# 15           0.821348         0.809089        0.032527               36
# 16           0.832072         0.825607        0.030253               18
# 17           0.836144         0.825085        0.029757               20
# 18           0.839024         0.815611        0.030917               30
# 19           0.844824         0.831774        0.028238               11
# 20           0.844006         0.833601        0.028749                4
# 21           0.829832         0.814073        0.029374               33
# 22           0.846312         0.830972        0.029764               13
# 23           0.839025         0.832631        0.028351                9
# 24           0.835456         0.812550        0.032764               34
# 25           0.831759         0.820829        0.026316               25
# 26           0.835343         0.821484        0.030315               24
# 27           0.838222         0.820383        0.031784               26
# 28           0.832338         0.830411        0.030561               15
# 29           0.840304         0.834733        0.029757                1
# 30           0.838817         0.822278        0.024157               23
# 31           0.842357         0.832766        0.027785                7
# 32           0.843238         0.834496        0.030127                2
# 33           0.826308         0.817016        0.027128               29
# 34           0.839202         0.824712        0.031019               21
# 35           0.842007         0.827240        0.032229               17

# %%
age_input=float(input("Age:"))
bmi_input=float(input("Bmi:"))
children=float(input("Children:"))
sex_male=int(input("Sex_Male 0 or 1:"))
smoker_yes=int(input("Smoker yes 0 or 1:"))
# Out:
# Age: 43
# Bmi: 31
# Children: 2
# Sex_Male 0 or 1: 0
# Smoker yes 0 or 1: 0

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children,sex_male,smoker_yes]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[8484.8898121]
# C:\anaconda\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
