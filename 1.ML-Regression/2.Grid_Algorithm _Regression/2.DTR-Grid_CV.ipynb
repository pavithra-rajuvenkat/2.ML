# %%
import pandas as pd
import numpy as np

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset= pd.get_dummies(dataset, dtype = int, drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[["charges"]]
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid= {'criterion':["squared_error", "friedman_mse", "absolute_error", "poisson"],'splitter':['best','random'], 'max_features':['sqrt', 'log2',None]}
grid=GridSearchCV(DecisionTreeRegressor(),param_grid,refit=True, verbose=3,n_jobs=-1)
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': ['sqrt', 'log2', None],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
re=grid.cv_results_
print("The R_score value for best parameter {}".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'criterion': 'squared_error', 'max_features': 'log2', 'splitter': 'best'}

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.020234      0.017435         0.022070        0.012343
# 1        0.021523      0.010347         0.013844        0.010261
# 2        0.013860      0.006102         0.009174        0.004807
# 3        0.020548      0.016927         0.009870        0.011485
# 4        0.023376      0.009596         0.008641        0.002635
# 5        0.024781      0.013466         0.007159        0.002445
# 6        0.016924      0.002379         0.006390        0.002448
# 7        0.022539      0.013465         0.007304        0.002494
# 8        0.023469      0.013310         0.012075        0.015442
# 9        0.028024      0.020713         0.010420        0.001427
# 10       0.022756      0.004889         0.007519        0.002957
# 11       0.014772      0.001305         0.007589        0.001043
# 12       0.096560      0.007389         0.024311        0.010603
# 13       0.072286      0.008898         0.016017        0.015214
# 14       0.084346      0.021751         0.017380        0.015247
# 15       0.052598      0.018252         0.020891        0.011807
# 16       0.143406      0.009801         0.022568        0.013139
# 17       0.114740      0.015639         0.020071        0.009792
# 18       0.023730      0.005327         0.017960        0.016919
# 19       0.023525      0.000695         0.008439        0.000691
# 20       0.029956      0.009142         0.015034        0.012010
# 21       0.018228      0.004438         0.006737        0.006082
# 22       0.038097      0.010723         0.012435        0.007118
# 23       0.027156      0.004545         0.008010        0.004990
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               sqrt           best
# 1    squared_error               sqrt         random
# 2    squared_error               log2           best
# 3    squared_error               log2         random
# 4    squared_error               None           best
# 5    squared_error               None         random
# 6     friedman_mse               sqrt           best
# 7     friedman_mse               sqrt         random
# 8     friedman_mse               log2           best
# 9     friedman_mse               log2         random
# 10    friedman_mse               None           best
# 11    friedman_mse               None         random
# 12  absolute_error               sqrt           best
# 13  absolute_error               sqrt         random
# 14  absolute_error               log2           best
# 15  absolute_error               log2         random
# 16  absolute_error               None           best
# 17  absolute_error               None         random
# 18         poisson               sqrt           best
# 19         poisson               sqrt         random
# 20         poisson               log2           best
# 21         poisson               log2         random
# 22         poisson               None           best
# 23         poisson               None         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.708575
# 1   {'criterion': 'squared_error', 'max_features':...           0.724295
# 2   {'criterion': 'squared_error', 'max_features':...           0.728318
# 3   {'criterion': 'squared_error', 'max_features':...           0.750350
# 4   {'criterion': 'squared_error', 'max_features':...           0.719538
# 5   {'criterion': 'squared_error', 'max_features':...           0.701117
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.716518
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.623503
# 8   {'criterion': 'friedman_mse', 'max_features': ...           0.686238
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.662167
# 10  {'criterion': 'friedman_mse', 'max_features': ...           0.726823
# 11  {'criterion': 'friedman_mse', 'max_features': ...           0.698584
# 12  {'criterion': 'absolute_error', 'max_features'...           0.726497
# 13  {'criterion': 'absolute_error', 'max_features'...           0.709882
# 14  {'criterion': 'absolute_error', 'max_features'...           0.661475
# 15  {'criterion': 'absolute_error', 'max_features'...           0.734281
# 16  {'criterion': 'absolute_error', 'max_features'...           0.750481
# 17  {'criterion': 'absolute_error', 'max_features'...           0.708760
# 18  {'criterion': 'poisson', 'max_features': 'sqrt...           0.778991
# 19  {'criterion': 'poisson', 'max_features': 'sqrt...           0.734151
# 20  {'criterion': 'poisson', 'max_features': 'log2...           0.722811
# 21  {'criterion': 'poisson', 'max_features': 'log2...           0.704336
# 22  {'criterion': 'poisson', 'max_features': None,...           0.732534
# 23  {'criterion': 'poisson', 'max_features': None,...           0.674312
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.328530           0.696428           0.542862
# 1            0.594536           0.693402           0.690413
# 2            0.678864           0.805074           0.688357
# 3            0.543540           0.688433           0.677904
# 4            0.652445           0.725514           0.728333
# 5            0.530019           0.696695           0.715761
# 6            0.573123           0.558446           0.723908
# 7            0.564913           0.664174           0.638383
# 8            0.590587           0.717873           0.723560
# 9            0.431144           0.606028           0.606188
# 10           0.660483           0.734274           0.740803
# 11           0.501408           0.735033           0.725879
# 12           0.636794           0.613532           0.725424
# 13           0.588884           0.725678           0.762734
# 14           0.635807           0.669067           0.690394
# 15           0.483938           0.618325           0.588431
# 16           0.628494           0.719270           0.715630
# 17           0.599988           0.688409           0.738544
# 18           0.639443           0.723743           0.646972
# 19           0.476237           0.598481           0.681191
# 20           0.587762           0.658139           0.721970
# 21           0.568612           0.678201           0.701210
# 22           0.652777           0.742429           0.712209
# 23           0.529005           0.721589           0.711299
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.686366         0.592552        0.145072               24
# 1            0.716671         0.683864        0.046528                9
# 2            0.718761         0.723875        0.044557                1
# 3            0.686260         0.669298        0.067989               14
# 4            0.670300         0.699226        0.031547                5
# 5            0.728750         0.674469        0.073104               13
# 6            0.731388         0.660676        0.077760               18
# 7            0.646496         0.627494        0.033933               21
# 8            0.677486         0.679149        0.047683               10
# 9            0.675124         0.596130        0.087202               23
# 10           0.676649         0.707807        0.032745                4
# 11           0.673549         0.666891        0.085506               15
# 12           0.722977         0.685045        0.049457                8
# 13           0.662226         0.689881        0.059924                7
# 14           0.729051         0.677159        0.031271               11
# 15           0.748425         0.634680        0.097967               20
# 16           0.743697         0.711514        0.043643                2
# 17           0.735196         0.694179        0.050534                6
# 18           0.590603         0.675951        0.066870               12
# 19           0.638623         0.625737        0.087279               22
# 20           0.623500         0.662836        0.053478               17
# 21           0.629489         0.656369        0.051404               19
# 22           0.703039         0.708597        0.031233                3
# 23           0.688763         0.664993        0.069988               16

# %%
age_input=float(input("Age:"))
bmi_input=float(input('Bmi'))
children=float(input("Children"))
sex_male=int(input("sex male 0 or 1"))
smoker_yes=int(input("Smoker yes 0 or 1"))
# Out:
# Age: 32
# Bmi 23
# Children 3
# sex male 0 or 1 0
# Smoker yes 0 or 1 0

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children,sex_male,smoker_yes]])
print("Future_Prediction:{}".format(Future_Prediction))
# Out:
# Future_Prediction:[7985.815]
# C:\anaconda\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
